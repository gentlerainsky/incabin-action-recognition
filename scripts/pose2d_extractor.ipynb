# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from modules.pose_extractor.pose2d_estimator.pose2d_estimator import Pose2DEstimator
from modules.pose_extractor.pose2d_estimator.pose2d_extractor import Pose2DExtractor
from IPython.display import display

# %%
video_root = Path('/root/data/raw/drive_and_act/')
# video_path = video_root / 'inner_mirror' / 'vp1' / 'run1b_2018-05-29-14-02-47.ids_1.mp4'
annotation_path = video_root / 'iccv_activities_3s' / 'activities_3s' / 'inner_mirror' / 'midlevel.chunks_90.csv'
pose_estimator_2d = Pose2DEstimator()
# Out:
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmpose/v1/body_2d_keypoint/topdown_heatmap/coco/td-hm_hrnet-w48_udp-8xb32-210e_coco-384x288-70d7ab01_20220913.pth
# 05/15 16:43:17 - mmengine - WARNING - Failed to search registry with scope "mmpose" in the "function" registry tree. As a workaround, the current "function" registry in "mmengine" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmpose" is a correct scope, or whether the registry is initialized.
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r50_fpn_1x_coco-person/faster_rcnn_r50_fpn_1x_coco-person_20201216_175929-d022e227.pth
# 05/15 16:43:18 - mmengine - WARNING - Failed to search registry with scope "mmdet" in the "function" registry tree. As a workaround, the current "function" registry in "mmengine" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmdet" is a correct scope, or whether the registry is initialized.

# %%
# split 0
# train 1,2,3,4,6,7,8,9,10,12
# val 14, 15
# test 5, 11, 13

# %%
extractor = Pose2DExtractor(
    video_root_path=video_root.as_posix(),
    data_subset='train',
    pose_estimator_2d=pose_estimator_2d,
    pickle_output_path='./output/inner_mirror_with_padding'
)
extractor.extract_2d_pose_from_annotation_file(annotation_path.as_posix())
# Out:
# 0.48% | Time used = 00:07:39
# 0.97% | Time used = 00:16:11
# 1.45% | Time used = 00:24:42
# 1.94% | Time used = 00:33:02
# 2.42% | Time used = 00:40:50
# 2.90% | Time used = 00:48:34
# 3.39% | Time used = 00:56:25
# 3.87% | Time used = 01:03:44
# 4.35% | Time used = 01:12:08
# 4.84% | Time used = 01:20:04
# 5.32% | Time used = 01:27:40
# 5.81% | Time used = 01:36:03
# 6.29% | Time used = 01:43:58
# 6.77% | Time used = 01:52:43
# 7.26% | Time used = 02:00:44
# 7.74% | Time used = 02:08:18
# 8.23% | Time used = 02:16:15
# 8.71% | Time used = 02:23:50
# 9.19% | Time used = 02:31:56
# 9.68% | Time used = 02:39:59
# 10.16% | Time used = 02:48:02
# 10.65% | Time used = 02:56:27
# 11.13% | Time used = 03:04:58
# 11.61% | Time used = 03:13:02
# 12.10% | Time used = 03:21:22
# 12.58% | Time used = 03:29:26
# 13.06% | Time used = 03:37:34
# 13.55% | Time used = 03:45:09
# 14.03% | Time used = 03:53:13
# 14.52% | Time used = 04:01:31
# 15.00% | Time used = 04:09:37
# 15.48% | Time used = 04:17:54
# 15.97% | Time used = 04:26:05
# 16.45% | Time used = 04:33:03
# 16.94% | Time used = 04:41:53
# 91.45% | Time used = 32:51:22
# 91.94% | Time used = 33:05:44
# 92.42% | Time used = 33:20:44
# 92.91% | Time used = 33:34:59
# 93.39% | Time used = 33:49:10
# 93.87% | Time used = 34:02:18
# 94.36% | Time used = 34:16:05
# 94.84% | Time used = 34:29:38
# 95.33% | Time used = 34:42:45
# 95.81% | Time used = 34:56:36
# 96.29% | Time used = 35:10:35
# 96.78% | Time used = 35:24:07
# 97.26% | Time used = 35:37:25
# 97.75% | Time used = 35:51:01
# 98.23% | Time used = 36:06:18
# 98.71% | Time used = 36:20:14
# 99.20% | Time used = 36:34:01
# 99.68% | Time used = 36:48:50

# %%
# %%time
# df = pd.read_csv(str(annotation_path))
# # with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
# #     display(df[df['participant_id'] == 1])
# df = df.set_index(['participant_id', 'file_id'])

# frame_info = []
# pose_2d_results = []
# current_video_name = None
# num_rows = df.shape[0]
# frame_count = 0
# annotation_count = 0
# for index, row in df.iterrows():
#     if (count + 1) % 100 == 0:
#         print(f'{((index + 1) / num_rows * 100):.2f}%')
#     annotation_count += 1
#     participant_id, video_name = index
#     if current_video_name != video_name:
#         video_file = str(video_path)
#         cap = cv2.VideoCapture(video_file)
#         total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
#         frame_rate = int(cap.get(cv2.CAP_PROP_FPS))
#         # in Hz
#         sampling_rate = 15
#         sampling_rate = int((1 / sampling_rate) * np.floor(frame_rate))
#     images = []
#     start = row['frame_start']
#     end = row['frame_end']
#     for frame_number in range(start, end, sampling_rate):
#         cap.set(cv2.CAP_PROP_POS_FRAMES, frame_number)
#         _, image = cap.read()
#         images.append(image)
#     bboxes, pose_2d_list, keypoint_2d_scores = pose_estimator_2d.inference(images)
#     for idx, image in enumerate(images):
#         frame_info.append(dict(
#             frame_index=annotation_count,
#             participant_id=participant_id,
#             video_name=video_name,
#             annotation_id=row['annotation_id'],
#             frame=start + idx,
#             activity=row['activity'],
#         ))
#         pose_2d_results.append(dict(
#             frame_index=annotation_count,
#             pose_2d=pose_2d_list[idx],
#             pose_2d_score=keypoint_2d_scores[idx],
#             pose_2d_avg_score=np.mean(keypoint_2d_scores[idx])
#         ))
#         frame_count += 1
#     break

# %%
# pose_2d_results

# %%
# frame_info

# %%
# fig, ax = plt.subplots()
# ax.imshow(images[10])
# ax.scatter(pose_2d_list[10][:, 0], pose_2d_list[10][:, 1])

# %%
# from mmpose.apis import MMPoseInferencer

# # img_path = 'tests/data/coco/000000000785.jpg'   # replace this with your own image path

# # instantiate the inferencer using the model alias
# inferencer = MMPoseInferencer('td-hm_ViTPose-large-simple_8xb64-210e_coco-256x192')

# # The MMPoseInferencer API employs a lazy inference approach,
# # creating a prediction generator when given input
# result_generator = inferencer(images[0], show=True)
# result = next(result_generator)
