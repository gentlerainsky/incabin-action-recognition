# %%
import pandas as pd

# %%
df = pd.read_csv('/root/data/raw/drive_and_act/iccv_activities_3s/activities_3s/inner_mirror/midlevel.chunks_90.csv')

# %%
df[df['file_id'] == 'vp1/run1b_2018-05-29-14-02-47.ids_1']
# Out:
#      participant_id                              file_id  annotation_id  \
# 0                 1  vp1/run1b_2018-05-29-14-02-47.ids_1              0
# 1                 1  vp1/run1b_2018-05-29-14-02-47.ids_1              1
# 2                 1  vp1/run1b_2018-05-29-14-02-47.ids_1              2
# 3                 1  vp1/run1b_2018-05-29-14-02-47.ids_1              3
# 4                 1  vp1/run1b_2018-05-29-14-02-47.ids_1              4
# ..              ...                                  ...            ...
# 362               1  vp1/run1b_2018-05-29-14-02-47.ids_1            141
# 363               1  vp1/run1b_2018-05-29-14-02-47.ids_1            142
# 364               1  vp1/run1b_2018-05-29-14-02-47.ids_1            143
# 365               1  vp1/run1b_2018-05-29-14-02-47.ids_1            144
# 366               1  vp1/run1b_2018-05-29-14-02-47.ids_1            145
#
#      frame_start  frame_end               activity  chunk_id
# ...
